# %%
import numpy as np
import corner
import scipy as sc
import matplotlib.pyplot as plt
from getdist import plots, loadMCSamples

# %%
chain = sc.genfromtxt('chainInt1_200events.txt')
one = np.ones((len(chain[:,0]),2))
chain = np.append(one, chain, axis=1)
np.savetxt('chainInt1_200eventsNew.txt', chain, fmt='%1.8e')

chain = sc.genfromtxt('chainInt1_500events.txt')
one = np.ones((len(chain[:,0]),2))
chain = np.append(one, chain, axis=1)
np.savetxt('chainInt1_500eventsNew.txt', chain, fmt='%1.8e')

chain = sc.genfromtxt('chainInt1_800events.txt')
one = np.ones((len(chain[:,0]),2))
chain = np.append(one, chain, axis=1)
np.savetxt('chainInt1_800eventsNew.txt', chain, fmt='%1.8e')

chain = sc.genfromtxt('chainInt1_1000events.txt')
one = np.ones((len(chain[:,0]),2))
chain = np.append(one, chain, axis=1)
np.savetxt('chainInt1_1000eventsNew.txt', chain, fmt='%1.8e')

chain = sc.genfromtxt('chainInt1.txt')
one = np.ones((len(chain[:,0]),2))
chain = np.append(one, chain, axis=1)
np.savetxt('chainInt1New.txt', chain, fmt='%1.8e')

# %%
#samples5 = loadMCSamples('/home/riisrhavia/GWcatalogo/Int1/chainInt1New')
samples200 = loadMCSamples('/home/riisrhavia/GWcatalogo/Int1/chainInt1_200eventsNew')
samples500 = loadMCSamples('/home/riisrhavia/GWcatalogo/Int1/chainInt1_500eventsNew')
samples800 = loadMCSamples('/home/riisrhavia/GWcatalogo/Int1/chainInt1_800eventsNew')
samples1000 = loadMCSamples('/home/riisrhavia/GWcatalogo/Int1/chainInt1_1000eventsNew')

g = plots.getSubplotPlotter()
g.triangle_plot([  samples200 , samples500 , samples800, samples1000],  ['Om_m', 'H_0', 'w', 'lamb'], filled=True, legend_labels=['200', '500', '800', '1000'], legend_loc='upper right', colors=['red', 'green', 'purple', 'blue'], line_args=[ {'color':'red'}, {'color':'green'}, {'color':'purple'}, {'color':'blue'}])

plt.savefig('contornosIM1.png')
plt.show()
# Out:
# /home/riisrhavia/GWcatalogo/Int1/chainInt1_200eventsNew.txt
# Removed no burn in
# /home/riisrhavia/.local/lib/python2.7/site-packages/getdist/chains.py:1052: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   weights = np.hstack((chain.weights for chain in self.chains))
# /home/riisrhavia/.local/lib/python2.7/site-packages/getdist/chains.py:1053: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   loglikes = np.hstack((chain.loglikes for chain in self.chains))
# ...

# %%
#1D marginalized plot
g = plots.getSinglePlotter(width_inch=4)
g.plot_1d([ samples500, samples1000], 'Om_m')

# %%
#1D marginalized comparison plot
g = plots.getSinglePlotter(width_inch=3)
g.plot_1d([samples1, samples2, samples3, samples4], 'w',  legend_labels=['200', '500', '800', '1000'], legend_loc='upper right', colors=['red', 'green', 'purple', 'blue'], line_args=[ {'color':'red'}, {'color':'green'}, {'color':'purple'}, {'color':'blue'}])

# %%
#1D marginalized comparison plot
g = plots.getSinglePlotter(width_inch=3)
g.plot_1d([samples200, samples500, samples800, samples1000], 'lamb',  legend_labels=['200', '500', '800', '1000'], legend_loc='upper right', colors=['red', 'green', 'purple', 'blue'], line_args=[ {'color':'red'}, {'color':'green'}, {'color':'purple'}, {'color':'blue'}])

# %%
#2D line contour comparison plot with extra bands and markers
g = plots.getSinglePlotter()
g.plot_2d([ samples3, samples2], 'w', 'lamb',  legend_labels=['200', '500', '800', '1000'], legend_loc='upper right', colors=['red', 'green', 'purple', 'blue'], line_args=[ {'color':'red'}, {'color':'green'}, {'color':'purple'}, {'color':'blue'}])
# Out:
# ((-2.8139486474604967, -0.6984349125395036),
#  (-0.3594121955479131, 0.3377127485479131))

# %%
#Filled 2D comparison plot with legend
g = plots.getSinglePlotter(width_inch=4, ratio=1)
g.plot_2d([samples200, samples500, samples800, samples1000], 'Om_m', 'lamb', filled=True)
g.add_legend(['200', '500', '800', '1000'], colored_text=True);

# %%
#Shaded 2D comparison plot
g = plots.getSinglePlotter(width_inch=4)
g.plot_2d([samples1000, samples500], 'Om_m', 'lamb', shaded=True);

# %%
#2D scatter (3D) plot
g = plots.getSinglePlotter(width_inch=5)
g.plot_3d(samples2, ['Om_m', 'H_0', 'lamb'])

# %%
#Multiple 2D subplots
g = plots.getSubplotPlotter(subplot_size=3.5)
g.plots_2d([samples2, samples3, samples4], param_pairs=[['Om_m', 'H_0'], ['Om_m', 'lamb']], 
           nx=2, filled=True);

# %%
#3D (scatter) triangle plot
g = plots.getSubplotPlotter(width_inch=6)
g.settings.axes_fontsize = 9
g.settings.legend_fontsize = 11
g.triangle_plot([ samples3], ['Om_m', 'H_0', 'lamb'], 
                plot_3d_with_param='w', 
                legend_labels=[ '1000'])

# %%
#Many other things you can do besides plot, e.g. get latex
#print(cut_samples.getInlineLatex('Om_m',limit=2))
print(samples4.getInlineLatex('Om_m',limit=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b8972852a81f> in <module>()
#       1 #Many other things you can do besides plot, e.g. get latex
#       2 #print(cut_samples.getInlineLatex('Om_m',limit=2))
# ----> 3 print(samples4.getInlineLatex('Om_m',limit=2))
#
# NameError: name 'samples4' is not defined

# %%
print(samples1000.getInlineLatex('Om_m',limit=1))
print(samples1000.getInlineLatex('H_0',limit=1))
print(samples1000.getInlineLatex('w',limit=1))
print(samples1000.getInlineLatex('lamb',limit=1))
# Out:
# \Omega_m = 0.342^{+0.065}_{-0.096}
# H_0 = 69.3^{+1.1}_{-1.4}
# \omega = -1.36^{+0.35}_{-0.066}
# \xi = 0.066^{+0.11}_{-0.090}

# %%
print(samples4.getTable(limit=1).tableTex())
# Out:
# \begin{tabular} { l  c}
#
#  Parameter &  68\% limits\\
# \hline
# {\boldmath$\Omega_m       $} & $0.342^{+0.065}_{-0.096}   $\\
#
# {\boldmath$H_0            $} & $69.3^{+1.1}_{-1.4}        $\\
#
# {\boldmath$\omega         $} & $-1.36^{+0.35}_{-0.066}    $\\
#
# {\boldmath$\xi            $} & $0.066^{+0.11}_{-0.090}    $\\
# \hline
# \end{tabular}

# %%
print([samples1.getTable(limit=1).tableTex(), samples4.getTable(limit=1).tableTex()])
# Out:
# ['\\begin{tabular} { l  c}\n\n Parameter &  68\\% limits\\\\\n\\hline\n{\\boldmath$\\Omega_m       $} & $0.327\\pm 0.047            $\\\\\n\n{\\boldmath$H_0            $} & $68.2^{+1.4}_{-2.0}        $\\\\\n\n{\\boldmath$\\omega         $} & $-1.32^{+0.31}_{-0.064}    $\\\\\n\n{\\boldmath$\\xi            $} & $0.097^{+0.20}_{-0.065}    $\\\\\n\\hline\n\\end{tabular}', '\\begin{tabular} { l  c}\n\n Parameter &  68\\% limits\\\\\n\\hline\n{\\boldmath$\\Omega_m       $} & $0.344^{+0.046}_{-0.035}   $\\\\\n\n{\\boldmath$H_0            $} & $68.6^{+1.0}_{-1.3}        $\\\\\n\n{\\boldmath$\\omega         $} & $-1.23^{+0.21}_{-0.062}    $\\\\\n\n{\\boldmath$\\xi            $} & $0.119^{+0.18}_{-0.055}    $\\\\\n\\hline\n\\end{tabular}']

# %%
print(samples4.PCA(['Om_m','H_0', 'w', 'lamb']))
# Out:
# PCA for parameters:
#          1 :ln(\Omega_m)
#          2 :ln(H_0)
#          3 :\omega
#          4 :\xi
#
# Correlation matrix for reduced parameters
#         Om_m :  1.0000 -0.1718 -0.5597  0.8850
#          H_0 : -0.1718  1.0000 -0.6419 -0.0965
#            w : -0.5597 -0.6419  1.0000 -0.4271
#         lamb :  0.8850 -0.0965 -0.4271  1.0000
#
# e-values of correlation matrix
# PC 1:   0.0192
# PC 2:   0.2182
# PC 3:   1.4732
# PC 4:   2.2894
#
# e-vectors
#   1: -0.6741 -0.3016 -0.2918  0.6079
#   2: -0.4133  0.4373  0.7870  0.1365
#   3: -0.5034  0.5119 -0.4580 -0.5241
#   4:  0.3484  0.6751 -0.2929  0.5807
#
# Principle components
# PC1 (e-value: 0.019242)
# [0.119698]  (\Omega_m/0.341966)^{1.000000}
# [0.073396]  (H_0/68.629698)^{4.197493}
# [0.089399]   exp((\omega--1.229413)/1.975694)
# [-0.061862]   exp((\xi-0.118747)/-2.231259)
#           = 1.000302 +- 0.024483
#
# PC2 (e-value: 0.218163)
# [-0.061670]  (\Omega_m/0.341966)^{-0.515214}
# ...

# %%
#Example of how to handle boundaries (samples are restricted to x0 >-0.5)
#cut_samps = samps[samps[:,0]>-0.5,:]
#cut_samples = MCSamples(samples=cut_samps, names = names, labels = labels, 
#                        ranges={'x0':(-0.5, None)})
#g = plots.getSubplotPlotter()
#g.plots_1d(cut_samples,nx=4);
#g = plots.getSinglePlotter(width_inch=4, ratio=1)
#g.plot_2d(cut_samples, 'x0', 'x1', filled=True);

samps1New = samples1[samples1[:,3]>0,:]
cut_samples = MCSamples(samples=samps1Ner, names = names, labels = labels, 
                        ranges={'lamb':(-0.5, None)})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-c154a7477a01> in <module>()
#      10 #g.plot_2d(cut_samples, 'x0', 'x1', filled=True);
#      11
# ---> 12 samps1New = samples1[samples1[:,3]>0,:]
#      13 cut_samples = MCSamples(samples=samps1Ner, names = names, labels = labels,
#      14                         ranges={'lamb':(-0.5, None)})
#
# TypeError: 'MCSamples' object has no attribute '__getitem__'

# %%
#Shaded 2D comparison plot
g = plots.getSinglePlotter(width_inch=4)
g.plot_2d([samples4, samples3], 'Om_m', 'H_0', shaded=True);

# %%
#Add and plot a new derived parameter
#getParms gets p so that p.x0, p.x1.. are numpy vectors of sample values
p = samples1000.getParams() 
samples1000.addDerived(1-p.Om_m, name='zy', label='\Omega_{d}')
g = plots.getSubplotPlotter()
g.plots_2d(samples1000,['H_0','zy'], nx=2, filled=True);

# %%
chain = sc.genfromtxt('chainInt1_100events.txt')
one = np.ones((len(chain[:,0]),2))
chain = np.append(one, chain, axis=1)
np.savetxt('chainInt1_100eventsNew.txt', chain, fmt='%1.8e')

chain = sc.genfromtxt('chainInt1_300events.txt')
one = np.ones((len(chain[:,0]),2))
chain = np.append(one, chain, axis=1)
np.savetxt('chainInt1_300eventsNew.txt', chain, fmt='%1.8e')

chain = sc.genfromtxt('chainInt1_400events.txt')
one = np.ones((len(chain[:,0]),2))
chain = np.append(one, chain, axis=1)
np.savetxt('chainInt1_400eventsNew.txt', chain, fmt='%1.8e')

chain = sc.genfromtxt('chainInt1_600events.txt')
one = np.ones((len(chain[:,0]),2))
chain = np.append(one, chain, axis=1)
np.savetxt('chainInt1_600eventsNew.txt', chain, fmt='%1.8e')

chain = sc.genfromtxt('chainInt1_700events.txt')
one = np.ones((len(chain[:,0]),2))
chain = np.append(one, chain, axis=1)
np.savetxt('chainInt1_700eventsNew.txt', chain, fmt='%1.8e')

chain = sc.genfromtxt('chainInt1_900events.txt')
one = np.ones((len(chain[:,0]),2))
chain = np.append(one, chain, axis=1)
np.savetxt('chainInt1_900eventsNew.txt', chain, fmt='%1.8e')

# %%
samples100 = loadMCSamples('/home/riisrhavia/GWcatalogo/Int1/chainInt1_100eventsNew')
samples300 = loadMCSamples('/home/riisrhavia/GWcatalogo/Int1/chainInt1_300eventsNew')
samples400 = loadMCSamples('/home/riisrhavia/GWcatalogo/Int1/chainInt1_400eventsNew')
samples600 = loadMCSamples('/home/riisrhavia/GWcatalogo/Int1/chainInt1_600eventsNew')
samples700 = loadMCSamples('/home/riisrhavia/GWcatalogo/Int1/chainInt1_700eventsNew')
samples900 = loadMCSamples('/home/riisrhavia/GWcatalogo/Int1/chainInt1_900eventsNew')
# Out:
# /home/riisrhavia/GWcatalogo/Int1/chainInt1_100eventsNew.txt
# Removed no burn in
# /home/riisrhavia/GWcatalogo/Int1/chainInt1_300eventsNew.txt
# Removed no burn in
# /home/riisrhavia/GWcatalogo/Int1/chainInt1_400eventsNew.txt
# Removed no burn in
# /home/riisrhavia/GWcatalogo/Int1/chainInt1_600eventsNew.txt
# Removed no burn in
# /home/riisrhavia/GWcatalogo/Int1/chainInt1_700eventsNew.txt
# Removed no burn in
# /home/riisrhavia/GWcatalogo/Int1/chainInt1_900eventsNew.txt
# Removed no burn in

# %%
#1D marginalized comparison plot
g = plots.getSinglePlotter(width_inch=3)
g.plot_1d([samples100, samples400 ,samples600, samples900], 'Om_m',  legend_labels=['100', '400', '600', '900'], legend_loc='upper right', colors=['red', 'green', 'purple', 'blue'], line_args=[ {'color':'red'}, {'color':'green'}, {'color':'purple'}, {'color':'blue'}])

# %%
g = plots.getSubplotPlotter()
g.triangle_plot([  samples100 , samples400 , samples600, samples900],  ['Om_m', 'H_0', 'w', 'lamb'], filled=True, legend_labels=['200', '500', '800', '1000'], legend_loc='upper right', colors=['red', 'green', 'purple', 'blue'], line_args=[ {'color':'red'}, {'color':'green'}, {'color':'purple'}, {'color':'blue'}])

plt.savefig('contornosIM1.png')
plt.show()

# %%
print(samples100.getInlineLatex('Om_m',limit=1))
print(samples100.getInlineLatex('H_0',limit=1))
print(samples100.getInlineLatex('w',limit=1))
print(samples100.getInlineLatex('lamb',limit=1))
# Out:
# \Omega_m = 0.55^{+0.16}_{-0.20}
# H_0 = 64.9^{+4.5}_{-7.2}
# \omega = -1.70\pm 0.46
# \xi = 0.158^{+0.12}_{-0.053}

# %%
print(samples1000.getTable(limit=1).tableTex())
# Out:
# \begin{tabular} { l  c}
#
#  Parameter &  68\% limits\\
# \hline
# {\boldmath$\Omega_m       $} & $0.342^{+0.065}_{-0.096}   $\\
#
# {\boldmath$H_0            $} & $69.3^{+1.1}_{-1.4}        $\\
#
# {\boldmath$\omega         $} & $-1.36^{+0.35}_{-0.066}    $\\
#
# {\boldmath$\xi            $} & $0.066^{+0.11}_{-0.090}    $\\
# \hline
# \end{tabular}

# %%
getdist.types.BestFit(fileName=samples1000, setParamNameFile=Om_m, want_fixed=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3c9b36008c60> in <module>()
# ----> 1 getdist.types.BestFit(fileName=samples1000, setParamNameFile=Om_m, want_fixed=False)
#
# NameError: name 'getdist' is not defined

# %%
print(samples1000.getInlineLatex('Om_m', BestFit))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-718c83bf4b66> in <module>()
# ----> 1 print(samples1000.getInlineLatex('Om_m',BestFit))
#
# NameError: name 'BestFit' is not defined

# %%
chain = sc.genfromtxt('chainIntISNH0BAO.txt')
one = np.ones((len(chain[:,0]),2))
chain = np.append(one, chain, axis=1)
np.savetxt('chainIntISNH0BAONew.txt', chain, fmt='%1.8e')

chain = sc.genfromtxt('chainIntISNH0BAOGW.txt')
one = np.ones((len(chain[:,0]),2))
chain = np.append(one, chain, axis=1)
np.savetxt('chainIntISNH0BAOGWNew.txt', chain, fmt='%1.8e')

# %%
samples1 = loadMCSamples('/home/riisrhavia/GWcatalogo/Int1/chainIntISNH0BAONew')
samples2 = loadMCSamples('/home/riisrhavia/GWcatalogo/Int1/chainIntISNH0BAOGWNew')
# Out:
# /home/riisrhavia/GWcatalogo/Int1/chainIntISNH0BAONew.txt
# Removed no burn in
# /home/riisrhavia/GWcatalogo/Int1/chainIntISNH0BAOGWNew.txt
# Removed no burn in

# %%
g = plots.getSubplotPlotter()
g.triangle_plot([  samples1, samples2],  ['Om_m', 'H_0', 'w', 'lamb'], filled=True, legend_labels=['SN+H(z)+BAO', 'SN+H(z)+BAO+GW'], legend_loc='upper right', colors=['red',  'blue'], line_args=[ {'color':'red'},  {'color':'blue'}])

plt.savefig('contornosIM1GW.png')
plt.show()

# %%
print(samples1.getInlineLatex('Om_m',limit=1))
print(samples1.getInlineLatex('H_0',limit=1))
print(samples1.getInlineLatex('w',limit=1))
print(samples1.getInlineLatex('lamb',limit=1))

print(samples2.getInlineLatex('Om_m',limit=1))
print(samples2.getInlineLatex('H_0',limit=1))
print(samples2.getInlineLatex('w',limit=1))
print(samples2.getInlineLatex('lamb',limit=1))
# Out:
# \Omega_m = 0.318\pm 0.016
# H_0 = 69.0\pm 1.6
# \omega = -1.096^{+0.049}_{-0.037}
# \xi = 0.020\pm 0.035
# \Omega_m = 0.309\pm 0.010
# H_0 = 67.60\pm 0.34
# \omega = -1.070^{+0.038}_{-0.026}
# \xi = 0.000\pm 0.022

# %%
xiGW=0.0007

# %%
0.34/1.6, 1.6/0.34
# Out:
# (0.2125, 4.705882352941177)

# %%
0.022/0.035, 0.035/0.022
# Out:
# (0.6285714285714284, 1.590909090909091)

# %%
#Shaded 2D comparison plot
g = plots.getSinglePlotter(width_inch=4)
g.plot_2d([samples2, samples1], 'Om_m', 'lamb', shaded=True);

# %%
#Shaded 2D comparison plot
g = plots.getSinglePlotter(width_inch=4)
g.plot_2d([samples2, samples1], 'H_0', 'lamb', shaded=True);

# %%
print(samples1.getTable(limit=1).tableTex())
# Out:
# \begin{tabular} { l  c}
#
#  Parameter &  68\% limits\\
# \hline
# {\boldmath$\Omega_m       $} & $0.318\pm 0.016            $\\
#
# {\boldmath$H_0            $} & $69.0\pm 1.6               $\\
#
# {\boldmath$\omega         $} & $-1.096^{+0.049}_{-0.037}  $\\
#
# {\boldmath$\xi            $} & $0.020\pm 0.035            $\\
# \hline
# \end{tabular}

# %%
print(samples2.getTable(limit=1).tableTex())
# Out:
# \begin{tabular} { l  c}
#
#  Parameter &  68\% limits\\
# \hline
# {\boldmath$\Omega_m       $} & $0.309\pm 0.010            $\\
#
# {\boldmath$H_0            $} & $67.60\pm 0.34             $\\
#
# {\boldmath$\omega         $} & $-1.070^{+0.038}_{-0.026}  $\\
#
# {\boldmath$\xi            $} & $0.000\pm 0.022            $\\
# \hline
# \end{tabular}
